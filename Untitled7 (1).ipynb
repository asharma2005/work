# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("/content/archive (4).zip")
df
# Out:
#        School DBN      Date  Enrolled  Absent  Present  Released
# 0          01M015  20180905       172      19      153         0
# 1          01M015  20180906       171      17      154         0
# 2          01M015  20180907       172      14      158         0
# 3          01M015  20180912       173       7      166         0
# 4          01M015  20180913       173       9      164         0
# ...           ...       ...       ...     ...      ...       ...
# 277148     79X695  20190620       230      46      136        48
# 277149     79X695  20190621       226      53      128        45
# 277150     79X695  20190624       226      42      130        54
# 277151     79X695  20190625       226      56      127        43
# 277152     79X695  20190626       216      27       68       121
#
# [277153 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# 1. Data Cleaning
# Check for missing values
print(df.isnull().sum())

# Check the data types of each column
print(df.dtypes)


# Check for duplicates and remove if necessary
print(f"Duplicate rows: {df.duplicated().sum()}")
df = df.drop_duplicates()

# 2. Summary Statistics
# Numerical columns summary statistics
print(df[['Enrolled', 'Absent', 'Present', 'Released']].describe())

# Categorical feature distribution (DBN)
print(df['School DBN'].value_counts())

# 3. Visualizations
# Time series analysis of the total attendance per day
df['Total Attendance'] = df['Present'] + df['Released']
plt.figure(figsize=(14, 7))
sns.lineplot(data=df, x='Date', y='Total Attendance')
plt.title('Total Attendance Over Time')
plt.xticks(rotation=45)
plt.show()

# Compare Absence vs Presence over time
plt.figure(figsize=(14, 7))
sns.lineplot(data=df, x='Date', y='Absent', label='Absent', color='red')
sns.lineplot(data=df, x='Date', y='Present', label='Present', color='green')
plt.title('Absence vs Presence Over Time')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Check the correlation between numerical features
corr = df[['Enrolled', 'Absent', 'Present', 'Released']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Between Attendance Features')
plt.show()

# # 4. Attendance Distribution by School (DBN)
# school_attendance = df.groupby('School DBN')[['Enrolled', 'Absent', 'Present', 'Released']].sum()
# school_attendance['Absence Rate'] = school_attendance['Absent'] / school_attendance['Enrolled']
# school_attendance['Presence Rate'] = school_attendance['Present'] / school_attendance['Enrolled']

# Plot Absence Rate by School
plt.figure(figsize=(12, 6))
sns.barplot(x=school_attendance.index, y=school_attendance['Absence Rate'])
plt.xticks(rotation=90)
plt.title('Absence Rate by School (DBN)')
plt.show()

# Plot Presence Rate by School
plt.figure(figsize=(12, 6))
sns.barplot(x=school_attendance.index, y=school_attendance['Presence Rate'])
plt.xticks(rotation=90)
plt.title('Presence Rate by School (DBN)')
plt.show()

# 5. Date-wise attendance analysis (e.g., for trends over months)
df['Month'] = df['Date'].dt.to_period('M')
monthly_attendance = df.groupby('Month')[['Absent', 'Present']].sum()

plt.figure(figsize=(14, 7))
sns.lineplot(data=monthly_attendance, x=monthly_attendance.index.astype(str), y='Absent', label='Absent', color='red')
sns.lineplot(data=monthly_attendance, x=monthly_attendance.index.astype(str), y='Present', label='Present', color='green')
plt.title('Monthly Attendance: Absence vs Presence')
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# School DBN          0
# Date                0
# Enrolled            0
# Absent              0
# Present             0
# Released            0
# Total Attendance    0
# Month               0
# dtype: int64
# School DBN                  object
# Date                datetime64[ns]
# Enrolled                     int64
# Absent                       int64
# Present                      int64
# Released                     int64
# Total Attendance             int64
# Month                    period[M]
# dtype: object
# Duplicate rows: 0
#            Enrolled         Absent        Present       Released
# count  277153.00000  277153.000000  277153.000000  277153.000000
# mean      596.98617      50.503538     544.499403       1.983229
# std       482.90966      54.329671     452.970313      35.114511
# min         1.00000       0.000000       1.000000       0.000000
# 25%       329.00000      23.000000     291.000000       0.000000
# ...
